# %% [markdown]
# ## Prerequisite:

# %%
import requests
from pymongo import MongoClient
api = 'http://api.nobelprize.org/v1/{}.json'

# %%
client = MongoClient('localhost',27017)
db = client['nobel_api']

# %%
words = ['prizes','laureates']

# %% [markdown]
# ### Note: When we use 'insert_one' than it should be a single object or dict in terms of python, but when we use 'insert_many' then it should be an array or list in terms of Python.

# %%
for word in words:
    singular=word[:-1]
    response = requests.get(api.format(singular))
    result = response.json()[word]
    db[word].insert_many(result)

# %% [markdown]
# ### Viewing collection in database:

# %%
db.collection_names(include_system_collections=False)
# Out:
# /home/khawajaosama/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: collection_names is deprecated. Use list_collection_names instead.
#   """Entry point for launching an IPython kernel.
# ['prizes', 'laureates']

# %%
result
# Out:
# [{'_id': ObjectId('5c49663d41ddc1194e9507f7'),
#   'born': '1845-03-27',
#   'bornCity': 'Lennep (now Remscheid)',
#   'bornCountry': 'Prussia (now Germany)',
#   'bornCountryCode': 'DE',
#   'died': '1923-02-10',
#   'diedCity': 'Munich',
#   'diedCountry': 'Germany',
#   'diedCountryCode': 'DE',
#   'firstname': 'Wilhelm Conrad',
#   'gender': 'male',
#   'id': '1',
#   'prizes': [{'affiliations': [{'city': 'Munich',
#       'country': 'Germany',
#       'name': 'Munich University'}],
#     'category': 'physics',
#     'motivation': '"in recognition of the extraordinary services he has rendered by the discovery of the remarkable rays subsequently named after him"',
#     'share': '1',
#     'year': '1901'}],
#   'surname': 'Röntgen'},
#  {'_id': ObjectId('5c49663d41ddc1194e9507f8'),
#   'born': '1853-07-18',
#   'bornCity': 'Arnhem',
#   'bornCountry': 'the Netherlands',
#   'bornCountryCode': 'NL',
#   'died': '1928-02-04',
#   'diedCountry': 'the Netherlands',
#   'diedCountryCode': 'NL',
#   'firstname': 'Hendrik Antoon',
#   'gender': 'male',
#   'id': '2',
#   'prizes': [{'affiliations': [{'city': 'Leiden',
#       'country': 'the Netherlands',
#       'name': 'Leiden University'}],
#     'category': 'physics',
#     'motivation': '"in recognition of the extraordinary service they rendered by their researches into the influence of magnetism upon radiation phenomena"',
#     'share': '2',
#     'year': '1902'}],
#   'surname': 'Lorentz'},
#  {'_id': ObjectId('5c49663d41ddc1194e9507f9'),
#   'born': '1865-05-25',
#   'bornCity': 'Zonnemaire',
#   'bornCountry': 'the Netherlands',
#   'bornCountryCode': 'NL',
#   'died': '1943-10-09',
#   'diedCity': 'Amsterdam',
#   'diedCountry': 'the Netherlands',
#   'diedCountryCode': 'NL',
#   'firstname': 'Pieter',
#   'gender': 'male',
#   'id': '3',
#   'prizes': [{'affiliations': [{'city': 'Amsterdam',
#       'country': 'the Netherlands',
#       'name': 'Amsterdam University'}],
#     'category': 'physics',
#     'motivation': '"in recognition of the extraordinary service they rendered by their researches into the influence of magnetism upon radiation phenomena"',
#     'share': '2',
#     'year': '1902'}],
#   'surname': 'Zeeman'},
#  {'_id': ObjectId('5c49663d41ddc1194e9507fa'),
#   'born': '1852-12-15',
#   'bornCity': 'Paris',
#   'bornCountry': 'France',
#   'bornCountryCode': 'FR',
#   'died': '1908-08-25',
#   'diedCountry': 'France',
#   'diedCountryCode': 'FR',
#   'firstname': 'Antoine Henri',
#   'gender': 'male',
#   'id': '4',
#   'prizes': [{'affiliations': [{'city': 'Paris',
#       'country': 'France',
#       'name': 'École Polytechnique'}],
#     'category': 'physics',
#     'motivation': '"in recognition of the extraordinary services he has rendered by his discovery of spontaneous radioactivity"',
#     'share': '2',
#     'year': '1903'}],
#   'surname': 'Becquerel'},
#  {'_id': ObjectId('5c49663d41ddc1194e9507fb'),
#   'born': '1859-05-15',
#   'bornCity': 'Paris',
#   'bornCountry': 'France',
#   'bornCountryCode': 'FR',
#   'died': '1906-04-19',
#   'diedCity': 'Paris',
#   'diedCountry': 'France',
#   'diedCountryCode': 'FR',
#   'firstname': 'Pierre',
#   'gender': 'male',
#   'id': '5',
#   'prizes': [{'affiliations': [{'city': 'Paris',
#       'country': 'France',
#       'name': 'École municipale de physique et de chimie industrielles (Municipal School of Industrial Physics and Chemistry)'}],
#     'category': 'physics',
#     'motivation': '"in recognition of the extraordinary services they have rendered by their joint researches on the radiation phenomena discovered by Professor Henri Becquerel"',
#     'share': '4',
#     'year': '1903'}],
#   'surname': 'Curie'},
#  {'_id': ObjectId('5c49663d41ddc1194e9507fc'),
#   'born': '1867-11-07',
#   'bornCity': 'Warsaw',
#   'bornCountry': 'Russian Empire (now Poland)',
#   'bornCountryCode': 'PL',
#   'died': '1934-07-04',
#   'diedCity': 'Sallanches',
#   'diedCountry': 'France',
#   'diedCountryCode': 'FR',
#   'firstname': 'Marie',
#   'gender': 'female',
#   'id': '6',
#   'prizes': [{'affiliations': [[]],
#     'category': 'physics',
#     'motivation': '"in recognition of the extraordinary services they have rendered by their joint researches on the radiation phenomena discovered by Professor Henri Becquerel"',
#     'share': '4',
#     'year': '1903'},
#    {'affiliations': [{'city': 'Paris',
#       'country': 'France',
#       'name': 'Sorbonne University'}],
#     'category': 'chemistry',
#     'motivation': '"in recognition of her services to the advancement of chemistry by the discovery of the elements radium and polonium, by the isolation of radium and the study of the nature and compounds of this remarkable element"',
#     'share': '1',
#     'year': '1911'}],
#   'surname': 'Curie, née Sklodowska'},
#  {'_id': ObjectId('5c49663d41ddc1194e9507fd'),
#   'born': '1842-11-12',
#   'bornCity': 'Langford Grove, Maldon, Essex',
#   'bornCountry': 'United Kingdom',
#   'bornCountryCode': 'GB',
#   'died': '1919-06-30',
#   'diedCountry': 'United Kingdom',
#   'diedCountryCode': 'GB',
#   'firstname': 'Lord Rayleigh',
#   'gender': 'male',
#   'id': '8',
#   'prizes': [{'affiliations': [{'city': 'London',
#       'country': 'United Kingdom',
#       'name': 'Royal Institution of Great Britain'}],
#     'category': 'physics',
#     'motivation': '"for his investigations of the densities of the most important gases and for his discovery of argon in connection with these studies"',
#     'share': '1',
#     'year': '1904'}],
#   'surname': '(John William Strutt)'},
#  {'_id': ObjectId('5c49663d41ddc1194e9507fe'),
#   'born': '1862-06-07',
#   'bornCity': 'Pressburg (now Bratislava)',
#   'bornCountry': 'Hungary (now Slovakia)',
#   'bornCountryCode': 'SK',
#   'died': '1947-05-20',
#   'diedCity': 'Messelhausen',
#   'diedCountry': 'Germany',
#   'diedCountryCode': 'DE',
#   'firstname': 'Philipp Eduard Anton',
#   'gender': 'male',
#   'id': '9',
#   'prizes': [{'affiliations': [{'city': 'Kiel',
#       'country': 'Germany',
#       'name': 'Kiel University'}],
#     'category': 'physics',
#     'motivation': '"for his work on cathode rays"',
#     'share': '1',
#     'year': '1905'}],
#   'surname': 'von Lenard'},
#  {'_id': ObjectId('5c49663d41ddc1194e9507ff'),
#   'born': '1856-12-18',
#   'bornCity': 'Cheetham Hill, near Manchester',
#   'bornCountry': 'United Kingdom',
#   'bornCountryCode': 'GB',
#   'died': '1940-08-30',
#   'diedCity': 'Cambridge',
#   'diedCountry': 'United Kingdom',
#   'diedCountryCode': 'GB',
#   'firstname': 'Joseph John',
#   'gender': 'male',
#   'id': '10',
#   'prizes': [{'affiliations': [{'city': 'Cambridge',
#       'country': 'United Kingdom',
#       'name': 'University of Cambridge'}],
#     'category': 'physics',
#     'motivation': '"in recognition of the great merits of his theoretical and experimental investigations on the conduction of electricity by gases"',
#     'share': '1',
#     'year': '1906'}],
#   'surname': 'Thomson'},
#  {'_id': ObjectId('5c49663d41ddc1194e950800'),
#   'born': '1852-12-19',
#   'bornCity': 'Strelno (now Strzelno)',
#   'bornCountry': 'Prussia (now Poland)',
#   'bornCountryCode': 'PL',
#   'died': '1931-05-09',
#   'diedCity': 'Pasadena, CA',
#   'diedCountry': 'USA',
#   'diedCountryCode': 'US',
#   'firstname': 'Albert Abraham',
#   'gender': 'male',
#   'id': '11',
#   'prizes': [{'affiliations': [{'city': 'Chicago, IL',
#       'country': 'USA',
#       'name': 'University of Chicago'}],
#     'category': 'physics',
#     'motivation': '"for his optical precision instruments and the spectroscopic and metrological investigations carried out with their aid"',
#     'share': '1',
#     'year': '1907'}],
#   'surname': 'Michelson'},
#  {'_id': ObjectId('5c49663d41ddc1194e950801'),
#   'born': '1845-08-16',
#   'bornCity': 'Hollerich',
#   'bornCountry': 'Luxembourg',
#   'bornCountryCode': 'LU',
#   'died': '1921-07-13',
#   'firstname': 'Gabriel',
#   'gender': 'male',
#   'id': '12',
#   'prizes': [{'affiliations': [{'city': 'Paris',
#       'country': 'France',
#       'name': 'Sorbonne University'}],
#     'category': 'physics',
#     'motivation': '"for his method of reproducing colours photographically based on the phenomenon of interference"',
#     'share': '1',
#     'year': '1908'}],
#   'surname': 'Lippmann'},
#  {'_id': ObjectId('5c49663d41ddc1194e950802'),
#   'born': '1874-04-25',
#   'bornCity': 'Bologna',
#   'bornCountry': 'Italy',
#   'bornCountryCode': 'IT',
#   'died': '1937-07-20',
#   'diedCity': 'Rome',
#   'diedCountry': 'Italy',
#   'diedCountryCode': 'IT',
#   'firstname': 'Guglielmo',
#   'gender': 'male',
#   'id': '13',
#   'prizes': [{'affiliations': [{'city': 'London',
#       'country': 'United Kingdom',
#       'name': 'Marconi Wireless Telegraph Co. Ltd.'}],
#     'category': 'physics',
#     'motivation': '"in recognition of their contributions to the development of wireless telegraphy"',
#     'share': '2',
#     'year': '1909'}],
#   'surname': 'Marconi'},
#  {'_id': ObjectId('5c49663d41ddc1194e950803'),
#   'born': '1850-06-06',
#   'bornCity': 'Fulda',
#   'bornCountry': 'Hesse-Kassel (now Germany)',
#   'bornCountryCode': 'DE',
#   'died': '1918-04-20',
#   'diedCity': 'Brooklyn, NY',
#   'diedCountry': 'USA',
#   'diedCountryCode': 'US',
#   'firstname': 'Karl Ferdinand',
#   'gender': 'male',
#   'id': '14',
#   'prizes': [{'affiliations': [{'city': 'Strasbourg',
#       'country': 'Alsace (then Germany, now France)',
#       'name': 'Strasbourg University'}],
#     'category': 'physics',
#     'motivation': '"in recognition of their contributions to the development of wireless telegraphy"',
#     'share': '2',
#     'year': '1909'}],
#   'surname': 'Braun'},
#  {'_id': ObjectId('5c49663d41ddc1194e950804'),
#   'born': '1837-11-23',
#   'bornCity': 'Leiden',
#   'bornCountry': 'the Netherlands',
#   'bornCountryCode': 'NL',
#   'died': '1923-03-08',
#   'diedCity': 'Amsterdam',
#   'diedCountry': 'the Netherlands',
#   'diedCountryCode': 'NL',
#   'firstname': 'Johannes Diderik',
#   'gender': 'male',
#   'id': '15',
#   'prizes': [{'affiliations': [{'city': 'Amsterdam',
#       'country': 'the Netherlands',
#       'name': 'Amsterdam University'}],
#     'category': 'physics',
#     'motivation': '"for his work on the equation of state for gases and liquids"',
#     'share': '1',
#     'year': '1910'}],
#   'surname': 'van der Waals'},
#  {'_id': ObjectId('5c49663d41ddc1194e950805'),
#   'born': '1864-01-13',
#   'bornCity': 'Gaffken (now Parusnoye)',
#   'bornCountry': 'Prussia (now Russia)',
#   'bornCountryCode': 'RU',
#   'died': '1928-08-30',
#   'diedCity': 'Munich',
#   'diedCountry': 'Germany',
#   'diedCountryCode': 'DE',
#   'firstname': 'Wilhelm',
#   'gender': 'male',
#   'id': '16',
#   'prizes': [{'affiliations': [{'city': 'Würzburg',
#       'country': 'Germany',
#       'name': 'Würzburg University'}],
#     'category': 'physics',
#     'motivation': '"for his discoveries regarding the laws governing the radiation of heat"',
#     'share': '1',
#     'year': '1911'}],
#   'surname': 'Wien'},
#  {'_id': ObjectId('5c49663d41ddc1194e950806'),
#   'born': '1869-11-30',
#   'bornCity': 'Stenstorp',
#   'bornCountry': 'Sweden',
#   'bornCountryCode': 'SE',
#   'died': '1937-12-09',
#   'diedCity': 'Stockholm',
#   'diedCountry': 'Sweden',
#   'diedCountryCode': 'SE',
#   'firstname': 'Nils Gustaf',
#   'gender': 'male',
#   'id': '17',
#   'prizes': [{'affiliations': [{'city': 'Lidingö-Stockholm',
#       'country': 'Sweden',
#       'name': 'Swedish Gas-Accumulator Co.'}],
#     'category': 'physics',
#     'motivation': '"for his invention of automatic regulators for use in conjunction with gas accumulators for illuminating lighthouses and buoys"',
#     'share': '1',
#     'year': '1912'}],
#   'surname': 'Dalén'},
#  {'_id': ObjectId('5c49663d41ddc1194e950807'),
#   'born': '1853-09-21',
#   'bornCity': 'Groningen',
#   'bornCountry': 'the Netherlands',
#   'bornCountryCode': 'NL',
#   'died': '1926-02-21',
#   'diedCity': 'Leiden',
#   'diedCountry': 'the Netherlands',
#   'diedCountryCode': 'NL',
#   'firstname': 'Heike',
#   'gender': 'male',
#   'id': '18',
#   'prizes': [{'affiliations': [{'city': 'Leiden',
#       'country': 'the Netherlands',
#       'name': 'Leiden University'}],
#     'category': 'physics',
#     'motivation': '"for his investigations on the properties of matter at low temperatures which led, inter alia, to the production of liquid helium"',
#     'share': '1',
#     'year': '1913'}],
#   'surname': 'Kamerlingh Onnes'},
#  {'_id': ObjectId('5c49663d41ddc1194e950808'),
#   'born': '1879-10-09',
#   'bornCity': 'Pfaffendorf',
#   'bornCountry': 'Germany',
#   'bornCountryCode': 'DE',
#   'died': '1960-04-23',
#   'diedCity': 'Berlin',
#   'diedCountry': 'West Germany (now Germany)',
#   'diedCountryCode': 'DE',
#   'firstname': 'Max',
#   'gender': 'male',
#   'id': '19',
#   'prizes': [{'affiliations': [{'city': 'Frankfurt-on-the-Main',
#       'country': 'Germany',
#       'name': 'Frankfurt-on-the-Main University'}],
#     'category': 'physics',
#     'motivation': '"for his discovery of the diffraction of X-rays by crystals"',
#     'share': '1',
#     'year': '1914'}],
#   'surname': 'von Laue'},
#  {'_id': ObjectId('5c49663d41ddc1194e950809'),
#   'born': '1862-07-02',
#   'bornCity': 'Wigton',
#   'bornCountry': 'United Kingdom',
#   'bornCountryCode': 'GB',
#   'died': '1942-03-12',
#   'diedCity': 'London',
#   'diedCountry': 'United Kingdom',
#   'diedCountryCode': 'GB',
#   'firstname': 'Sir William Henry',
#   'gender': 'male',
#   'id': '20',
#   'prizes': [{'affiliations': [{'city': 'London',
#       'country': 'United Kingdom',
#       'name': 'University College'}],
#     'category': 'physics',
#     'motivation': '"for their services in the analysis of crystal structure by means of X-rays"',
#     'share': '2',
#     'year': '1915'}],
#   'surname': 'Bragg'},
#  {'_id': ObjectId('5c49663d41ddc1194e95080a'),
#   'born': '1890-03-31',
#   'bornCity': 'Adelaide',
#   'bornCountry': 'Australia',
#   'bornCountryCode': 'AU',
#   'died': '1971-07-01',
#   'diedCity': 'Ipswich',
#   'diedCountry': 'United Kingdom',
#   'diedCountryCode': 'GB',
#   'firstname': 'William Lawrence',
#   'gender': 'male',
#   'id': '21',
#   'prizes': [{'affiliations': [{'city': 'Manchester',
#       'country': 'United Kingdom',
#       'name': 'Victoria University'}],
#     'category': 'physics',
#     'motivation': '"for their services in the analysis of crystal structure by means of X-rays"',
#     'share': '2',
#     'year': '1915'}],
#   'surname': 'Bragg'},
#  {'_id': ObjectId('5c49663d41ddc1194e95080b'),
#   'born': '1877-06-07',
#   'bornCity': 'Widnes',
#   'bornCountry': 'United Kingdom',
#   'bornCountryCode': 'GB',
#   'died': '1944-10-23',
#   'diedCity': 'Edinburgh',
#   'diedCountry': 'Scotland',
#   'diedCountryCode': 'GB',
#   'firstname': 'Charles Glover',
#   'gender': 'male',
#   'id': '22',
#   'prizes': [{'affiliations': [{'city': 'Edinburgh',
#       'country': 'United Kingdom',
#       'name': 'Edinburgh University'}],
#     'category': 'physics',
#     'motivation': '"for his discovery of the characteristic R&ouml;ntgen radiation of the elements"',
#     'share': '1',
#     'year': '1917'}],
#   'surname': 'Barkla'},
#  {'_id': ObjectId('5c49663d41ddc1194e95080c'),
#   'born': '1858-04-23',
#   'bornCity': 'Kiel',
#   'bornCountry': 'Schleswig (now Germany)',
#   'bornCountryCode': 'DE',
#   'died': '1947-10-04',
#   'diedCity': 'Göttingen',
#   'diedCountry': 'West Germany (now Germany)',
#   'diedCountryCode': 'DE',
#   'firstname': 'Max Karl Ernst Ludwig',
#   'gender': 'male',
#   'id': '23',
#   'prizes': [{'affiliations': [{'city': 'Berlin',
#       'country': 'Germany',
#       'name': 'Berlin University'}],
#     'category': 'physics',
#     'motivation': '"in recognition of the services he rendered to the advancement of Physics by his discovery of energy quanta"',
#     'share': '1',
#     'year': '1918'}],
#   'surname': 'Planck'},
#  {'_id': ObjectId('5c49663d41ddc1194e95080d'),
#   'born': '1874-04-15',
#   'bornCity': 'Schickenhof',
#   'bornCountry': 'Germany',
#   'bornCountryCode': 'DE',
#   'died': '1957-06-21',
#   'diedCity': 'Traunstein',
#   'diedCountry': 'West Germany (now Germany)',
#   'diedCountryCode': 'DE',
#   'firstname': 'Johannes',
#   'gender': 'male',
#   'id': '24',
#   'prizes': [{'affiliations': [{'city': 'Greifswald',
#       'country': 'Germany',
#       'name': 'Greifswald University'}],
#     'category': 'physics',
#     'motivation': '"for his discovery of the Doppler effect in canal rays and the splitting of spectral lines in electric fields"',
#     'share': '1',
#     'year': '1919'}],
#   'surname': 'Stark'},
#  {'_id': ObjectId('5c49663d41ddc1194e95080e'),
#   'born': '1861-02-15',
#   'bornCity': 'Fleurier',
#   'bornCountry': 'Switzerland',
#   'bornCountryCode': 'CH',
#   'died': '1938-06-13',
#   'diedCity': 'Sèvres',
#   'diedCountry': 'France',
#   'diedCountryCode': 'FR',
#   'firstname': 'Charles Edouard',
#   'gender': 'male',
#   'id': '25',
#   'prizes': [{'affiliations': [{'city': 'Sèvres',
#       'country': 'France',
#       'name': 'Bureau International des Poids et Mesures (International Bureau of Weights and Measures)'}],
#     'category': 'physics',
#     'motivation': '"in recognition of the service he has rendered to precision measurements in Physics by his discovery of anomalies in nickel steel alloys"',
#     'share': '1',
#     'year': '1920'}],
#   'surname': 'Guillaume'},
#  {'_id': ObjectId('5c49663d41ddc1194e95080f'),
#   'born': '1879-03-14',
#   'bornCity': 'Ulm',
#   'bornCountry': 'Germany',
#   'bornCountryCode': 'DE',
#   'died': '1955-04-18',
#   'diedCity': 'Princeton, NJ',
#   'diedCountry': 'USA',
#   'diedCountryCode': 'US',
#   'firstname': 'Albert',
#   'gender': 'male',
#   'id': '26',
#   'prizes': [{'affiliations': [{'city': 'Berlin',
#       'country': 'Germany',
#       'name': 'Kaiser-Wilhelm-Institut (now Max-Planck-Institut) für Physik'}],
#     'category': 'physics',
#     'motivation': '"for his services to Theoretical Physics, and especially for his discovery of the law of the photoelectric effect"',
#     'share': '1',
#     'year': '1921'}],
#   'surname': 'Einstein'},
#  {'_id': ObjectId('5c49663d41ddc1194e950810'),
#   'born': '1885-10-07',
#   'bornCity': 'Copenhagen',
#   'bornCountry': 'Denmark',
#   'bornCountryCode': 'DK',
#   'died': '1962-11-18',
#   'diedCity': 'Copenhagen',
#   'diedCountry': 'Denmark',
#   'diedCountryCode': 'DK',
#   'firstname': 'Niels Henrik David',
#   'gender': 'male',
#   'id': '27',
#   'prizes': [{'affiliations': [{'city': 'Copenhagen',
#       'country': 'Denmark',
#       'name': 'Copenhagen University'}],
#     'category': 'physics',
#     'motivation': '"for his services in the investigation of the structure of atoms and of the radiation emanating from them"',
#     'share': '1',
#     'year': '1922'}],
#   'surname': 'Bohr'},
#  {'_id': ObjectId('5c49663d41ddc1194e950811'),
#   'born': '1868-03-22',
#   'bornCity': 'Morrison, IL',
#   'bornCountry': 'USA',
#   'bornCountryCode': 'US',
#   'died': '1953-12-19',
#   'diedCity': 'San Marino, CA',
#   'diedCountry': 'USA',
#   'diedCountryCode': 'US',
#   'firstname': 'Robert Andrews',
#   'gender': 'male',
#   'id': '28',
#   'prizes': [{'affiliations': [{'city': 'Pasadena, CA',
#       'country': 'USA',
#       'name': 'California Institute of Technology (Caltech)'}],
#     'category': 'physics',
#     'motivation': '"for his work on the elementary charge of electricity and on the photoelectric effect"',
#     'share': '1',
#     'year': '1923'}],
#   'surname': 'Millikan'},
#  {'_id': ObjectId('5c49663d41ddc1194e950812'),
#   'born': '1886-12-03',
#   'bornCity': 'Örebro',
#   'bornCountry': 'Sweden',
#   'bornCountryCode': 'SE',
#   'died': '1978-09-26',
#   'diedCity': 'Stockholm',
#   'diedCountry': 'Sweden',
#   'diedCountryCode': 'SE',
#   'firstname': 'Karl Manne Georg',
#   'gender': 'male',
#   'id': '29',
#   'prizes': [{'affiliations': [{'city': 'Uppsala',
#       'country': 'Sweden',
#       'name': 'Uppsala University'}],
#     'category': 'physics',
#     'motivation': '"for his discoveries and research in the field of X-ray spectroscopy"',
#     'share': '1',
#     'year': '1924'}],
#   'surname': 'Siegbahn'},
#  {'_id': ObjectId('5c49663d41ddc1194e950813'),
#   'born': '1882-08-26',
#   'bornCity': 'Hamburg',
#   'bornCountry': 'Germany',
#   'bornCountryCode': 'DE',
#   'died': '1964-05-21',
#   'diedCity': 'Göttingen',
#   'diedCountry': 'West Germany (now Germany)',
#   'diedCountryCode': 'DE',
#   'firstname': 'James',
#   'gender': 'male',
#   'id': '30',
#   'prizes': [{'affiliations': [{'city': 'Göttingen',
#       'country': 'Germany',
#       'name': 'Goettingen University'}],
#     'category': 'physics',
#     'motivation': '"for their discovery of the laws governing the impact of an electron upon an atom"',
#     'share': '2',
#     'year': '1925'}],
#   'surname': 'Franck'},
#  {'_id': ObjectId('5c49663d41ddc1194e950814'),
#   'born': '1887-07-22',
#   'bornCity': 'Hamburg',
#   'bornCountry': 'Germany',
#   'bornCountryCode': 'DE',
#   'died': '1975-10-30',
#   'diedCity': 'Berlin',
#   'diedCountry': 'East Germany',
#   'diedCountryCode': 'DE',
#   'firstname': 'Gustav Ludwig',
#   'gender': 'male',
#   'id': '31',
#   'prizes': [{'affiliations': [{'city': 'Halle',
#       'country': 'Germany',
#       'name': 'Halle University'}],
#     'category': 'physics',
#     'motivation': '"for their discovery of the laws governing the impact of an electron upon an atom"',
#     'share': '2',
#     'year': '1925'}],
#   'surname': 'Hertz'},
#  {'_id': ObjectId('5c49663d41ddc1194e950815'),
#   'born': '1870-09-30',
#   'bornCity': 'Lille',
#   'bornCountry': 'France',
#   'bornCountryCode': 'FR',
#   'died': '1942-04-17',
#   'diedCity': 'New York, NY',
#   'diedCountry': 'USA',
#   'diedCountryCode': 'US',
#   'firstname': 'Jean Baptiste',
#   'gender': 'male',
#   'id': '32',
#   'prizes': [{'affiliations': [{'city': 'Paris',
#       'country': 'France',
#       'name': 'Sorbonne University'}],
#     'category': 'physics',
#     'motivation': '"for his work on the discontinuous structure of matter, and especially for his discovery of sedimentation equilibrium"',
#     'share': '1',
#     'year': '1926'}],
#   'surname': 'Perrin'},
#  {'_id': ObjectId('5c49663d41ddc1194e950816'),
#   'born': '1892-09-10',
#   'bornCity': 'Wooster, OH',
#   'bornCountry': 'USA',
#   'bornCountryCode': 'US',
#   'died': '1962-03-15',
#   'diedCity': 'Berkeley, CA',
#   'diedCountry': 'USA',
#   'diedCountryCode': 'US',
#   'firstname': 'Arthur Holly',
#   'gender': 'male',
#   'id': '33',
#   'prizes': [{'affiliations': [{'city': 'Chicago, IL',
#       'country': 'USA',
#       'name': 'University of Chicago'}],
#     'category': 'physics',
#     'motivation': '"for his discovery of the effect named after him"',
#     'share': '2',
#     'year': '1927'}],
#   'surname': 'Compton'},
#  {'_id': ObjectId('5c49663d41ddc1194e950817'),
#   'born': '1869-02-14',
#   'bornCity': 'Glencorse',
#   'bornCountry': 'Scotland',
#   'bornCountryCode': 'GB',
#   'died': '1959-11-15',
#   'diedCity': 'Carlops',
#   'diedCountry': 'Scotland',
#   'diedCountryCode': 'GB',
#   'firstname': 'Charles Thomson Rees',
#   'gender': 'male',
#   'id': '34',
#   'prizes': [{'affiliations': [{'city': 'Cambridge',
#       'country': 'United Kingdom',
#       'name': 'University of Cambridge'}],
#     'category': 'physics',
#     'motivation': '"for his method of making the paths of electrically charged particles visible by condensation of vapour"',
#     'share': '2',
#     'year': '1927'}],
#   'surname': 'Wilson'},
#  {'_id': ObjectId('5c49663d41ddc1194e950818'),
#   'born': '1879-04-26',
#   'bornCity': 'Dewsbury',
#   'bornCountry': 'United Kingdom',
#   'bornCountryCode': 'GB',
#   'died': '1959-02-15',
#   'diedCity': 'Alton',
#   'diedCountry': 'United Kingdom',
#   'diedCountryCode': 'GB',
#   'firstname': 'Owen Willans',
#   'gender': 'male',
#   'id': '35',
#   'prizes': [{'affiliations': [{'city': 'London',
#       'country': 'United Kingdom',
#       'name': 'London University'}],
#     'category': 'physics',
#     'motivation': '"for his work on the thermionic phenomenon and especially for the discovery of the law named after him"',
#     'share': '1',
#     'year': '1928'}],
#   'surname': 'Richardson'},
#  {'_id': ObjectId('5c49663d41ddc1194e950819'),
#   'born': '1892-08-15',
#   'bornCity': 'Dieppe',
#   'bornCountry': 'France',
#   'bornCountryCode': 'FR',
#   'died': '1987-03-19',
#   'diedCity': 'Paris',
#   'diedCountry': 'France',
#   'diedCountryCode': 'FR',
#   'firstname': 'Prince Louis-Victor Pierre Raymond',
#   'gender': 'male',
#   'id': '36',
#   'prizes': [{'affiliations': [{'city': 'Paris',
#       'country': 'France',
#       'name': 'Sorbonne University, Institut Henri Poincaré'}],
#     'category': 'physics',
#     'motivation': '"for his discovery of the wave nature of electrons"',
#     'share': '1',
#     'year': '1929'}],
#   'surname': 'de Broglie'},
#  {'_id': ObjectId('5c49663d41ddc1194e95081a'),
#   'born': '1888-11-07',
#   'bornCity': 'Tiruchirappalli',
#   'bornCountry': 'India',
#   'bornCountryCode': 'IN',
#   'died': '1970-11-21',
#   'diedCity': 'Bangalore',
#   'diedCountry': 'India',
#   'diedCountryCode': 'IN',
#   'firstname': 'Sir Chandrasekhara Venkata',
#   'gender': 'male',
#   'id': '37',
#   'prizes': [{'affiliations': [{'city': 'Calcutta',
#       'country': 'India',
#       'name': 'Calcutta University'}],
#     'category': 'physics',
#     'motivation': '"for his work on the scattering of light and for the discovery of the effect named after him"',
#     'share': '1',
#     'year': '1930'}],
#   'surname': 'Raman'},
#  {'_id': ObjectId('5c49663d41ddc1194e95081b'),
#   'born': '1901-12-05',
#   'bornCity': 'Würzburg',
#   'bornCountry': 'Germany',
#   'bornCountryCode': 'DE',
#   'died': '1976-02-01',
#   'diedCity': 'Munich',
#   'diedCountry': 'West Germany (now Germany)',
#   'diedCountryCode': 'DE',
#   'firstname': 'Werner Karl',
#   'gender': 'male',
#   'id': '38',
#   'prizes': [{'affiliations': [{'city': 'Leipzig',
#       'country': 'Germany',
#       'name': 'Leipzig University'}],
#     'category': 'physics',
#     'motivation': '"for the creation of quantum mechanics, the application of which has, inter alia, led to the discovery of the allotropic forms of hydrogen"',
#     'share': '1',
#     'year': '1932'}],
#   'surname': 'Heisenberg'},
#  {'_id': ObjectId('5c49663d41ddc1194e95081c'),
#   'born': '1887-08-12',
#   'bornCity': 'Vienna',
#   'bornCountry': 'Austria',
#   'bornCountryCode': 'AT',
#   'died': '1961-01-04',
#   'diedCity': 'Vienna',
#   'diedCountry': 'Austria',
#   'diedCountryCode': 'AT',
#   'firstname': 'Erwin',
#   'gender': 'male',
#   'id': '39',
#   'prizes': [{'affiliations': [{'city': 'Berlin',
#       'country': 'Germany',
#       'name': 'Berlin University'}],
#     'category': 'physics',
#     'motivation': '"for the discovery of new productive forms of atomic theory"',
#     'share': '2',
#     'year': '1933'}],
#   'surname': 'Schrödinger'},
#  {'_id': ObjectId('5c49663d41ddc1194e95081d'),
#   'born': '1902-08-08',
#   'bornCity': 'Bristol',
#   'bornCountry': 'United Kingdom',
#   'bornCountryCode': 'GB',
#   'died': '1984-10-20',
#   'diedCity': 'Tallahassee, FL',
#   'diedCountry': 'USA',
#   'diedCountryCode': 'US',
#   'firstname': 'Paul Adrien Maurice',
#   'gender': 'male',
#   'id': '40',
#   'prizes': [{'affiliations': [{'city': 'Cambridge',
#       'country': 'United Kingdom',
#       'name': 'University of Cambridge'}],
#     'category': 'physics',
#     'motivation': '"for the discovery of new productive forms of atomic theory"',
#     'share': '2',
#     'year': '1933'}],
#   'surname': 'Dirac'},
#  {'_id': ObjectId('5c49663d41ddc1194e95081e'),
#   'born': '1891-10-20',
#   'bornCity': 'Manchester',
#   'bornCountry': 'United Kingdom',
#   'bornCountryCode': 'GB',
#   'died': '1974-07-24',
#   'diedCity': 'Cambridge',
#   'diedCountry': 'United Kingdom',
#   'diedCountryCode': 'GB',
#   'firstname': 'James',
#   'gender': 'male',
#   'id': '41',
#   'prizes': [{'affiliations': [{'city': 'Liverpool',
#       'country': 'United Kingdom',
#       'name': 'Liverpool University'}],
#     'category': 'physics',
#     'motivation': '"for the discovery of the neutron"',
#     'share': '1',
#     'year': '1935'}],
#   'surname': 'Chadwick'},
#  {'_id': ObjectId('5c49663d41ddc1194e95081f'),
#   'born': '1883-06-24',
#   'bornCity': 'Peggau',
#   'bornCountry': 'Austria',
#   'bornCountryCode': 'AT',
#   'died': '1964-12-17',
#   'diedCity': 'Mount Verno, NY',
#   'diedCountry': 'USA',
#   'diedCountryCode': 'US',
#   'firstname': 'Victor Franz',
#   'gender': 'male',
#   'id': '42',
#   'prizes': [{'affiliations': [{'city': 'Innsbruck',
#       'country': 'Austria',
#       'name': 'Innsbruck University'}],
#     'category': 'physics',
#     'motivation': '"for his discovery of cosmic radiation"',
#     'share': '2',
#     'year': '1936'}],
#   'surname': 'Hess'},
#  {'_id': ObjectId('5c49663d41ddc1194e950820'),
#   'born': '1905-09-03',
#   'bornCity': 'New York, NY',
#   'bornCountry': 'USA',
#   'bornCountryCode': 'US',
#   'died': '1991-01-11',
#   'diedCity': 'San Marino, CA',
#   'diedCountry': 'USA',
#   'diedCountryCode': 'US',
#   'firstname': 'Carl David',
#   'gender': 'male',
#   'id': '43',
#   'prizes': [{'affiliations': [{'city': 'Pasadena, CA',
#       'country': 'USA',
#       'name': 'California Institute of Technology (Caltech)'}],
#     'category': 'physics',
#     'motivation': '"for his discovery of the positron"',
#     'share': '2',
#     'year': '1936'}],
#   'surname': 'Anderson'},
#  {'_id': ObjectId('5c49663d41ddc1194e950821'),
#   'born': '1881-10-22',
#   'bornCity': 'Bloomington, IL',
#   'bornCountry': 'USA',
#   'bornCountryCode': 'US',
#   'died': '1958-02-01',
#   'diedCity': 'Charlottesville, VA',
#   'diedCountry': 'USA',
#   'diedCountryCode': 'US',
#   'firstname': 'Clinton Joseph',
#   'gender': 'male',
#   'id': '44',
#   'prizes': [{'affiliations': [{'city': 'New York, NY',
#       'country': 'USA',
#       'name': 'Bell Telephone Laboratories'}],
#     'category': 'physics',
#     'motivation': '"for their experimental discovery of the diffraction of electrons by crystals"',
#     'share': '2',
#     'year': '1937'}],
#   'surname': 'Davisson'},
#  {'_id': ObjectId('5c49663d41ddc1194e950822'),
#   'born': '1892-05-03',
#   'bornCity': 'Cambridge',
#   'bornCountry': 'United Kingdom',
#   'bornCountryCode': 'GB',
#   'died': '1975-09-10',
#   'diedCity': 'Cambridge',
#   'diedCountry': 'United Kingdom',
#   'diedCountryCode': 'GB',
#   'firstname': 'George Paget',
#   'gender': 'male',
#   'id': '45',
#   'prizes': [{'affiliations': [{'city': 'London',
#       'country': 'United Kingdom',
#       'name': 'London University'}],
#     'category': 'physics',
#     'motivation': '"for their experimental discovery of the diffraction of electrons by crystals"',
#     'share': '2',
#     'year': '1937'}],
#   'surname': 'Thomson'},
#  {'_id': ObjectId('5c49663d41ddc1194e950823'),
#   'born': '1901-09-29',
#   'bornCity': 'Rome',
#   'bornCountry': 'Italy',
#   'bornCountryCode': 'IT',
#   'died': '1954-11-28',
#   'diedCity': 'Chicago, IL',
#   'diedCountry': 'USA',
#   'diedCountryCode': 'US',
#   'firstname': 'Enrico',
#   'gender': 'male',
#   'id': '46',
#   'prizes': [{'affiliations': [{'city': 'Rome',
#       'country': 'Italy',
#       'name': 'Rome University'}],
#     'category': 'physics',
#     'motivation': '"for his demonstrations of the existence of new radioactive elements produced by neutron irradiation, and for his related discovery of nuclear reactions brought about by slow neutrons"',
#     'share': '1',
#     'year': '1938'}],
#   'surname': 'Fermi'},
#  {'_id': ObjectId('5c49663d41ddc1194e950824'),
#   'born': '1901-08-08',
#   'bornCity': 'Canton, SD',
#   'bornCountry': 'USA',
#   'bornCountryCode': 'US',
#   'died': '1958-08-27',
#   'diedCity': 'Palo Alto, CA',
#   'diedCountry': 'USA',
#   'diedCountryCode': 'US',
#   'firstname': 'Ernest Orlando',
#   'gender': 'male',
#   'id': '47',
#   'prizes': [{'affiliations': [{'city': 'Berkeley, CA',
#       'country': 'USA',
#       'name': 'University of California'}],
#     'category': 'physics',
#     'motivation': '"for the invention and development of the cyclotron and for results obtained with it, especially with regard to artificial radioactive elements"',
#     'share': '1',
#     'year': '1939'}],
#   'surname': 'Lawrence'},
#  {'_id': ObjectId('5c49663d41ddc1194e950825'),
#   'born': '1888-02-17',
#   'bornCity': 'Sorau (now Zory)',
#   'bornCountry': 'Germany (now Poland)',
#   'bornCountryCode': 'PL',
#   'died': '1969-08-17',
#   'diedCity': 'Berkeley, CA',
#   'diedCountry': 'USA',
#   'diedCountryCode': 'US',
#   'firstname': 'Otto',
#   'gender': 'male',
#   'id': '48',
#   'prizes': [{'affiliations': [{'city': 'Pittsburgh, PA',
#       'country': 'USA',
#       'name': 'Carnegie Institute of Technology'}],
#     'category': 'physics',
#     'motivation': '"for his contribution to the development of the molecular ray method and his discovery of the magnetic moment of the proton"',
#     'share': '1',
#     'year': '1943'}],
#   'surname': 'Stern'},
#  {'_id': ObjectId('5c49663d41ddc1194e950826'),
#   'born': '1898-07-29',
#   'bornCity': 'Rymanow',
#   'bornCountry': 'Austria-Hungary (now Poland)',
#   'bornCountryCode': 'PL',
#   'died': '1988-01-11',
#   'diedCity': 'New York, NY',
#   'diedCountry': 'USA',
#   'diedCountryCode': 'US',
#   'firstname': 'Isidor Isaac',
#   'gender': 'male',
#   'id': '49',
#   'prizes': [{'affiliations': [{'city': 'New York, NY',
#       'country': 'USA',
#       'name': 'Columbia University'}],
#     'category': 'physics',
#     'motivation': '"for his resonance method for recording the magnetic properties of atomic nuclei"',
#     'share': '1',
#     'year': '1944'}],
#   'surname': 'Rabi'},
#  {'_id': ObjectId('5c49663d41ddc1194e950827'),
#   'born': '1900-04-25',
#   'bornCity': 'Vienna',
#   'bornCountry': 'Austria',
#   'bornCountryCode': 'AT',
#   'died': '1958-12-15',
#   'diedCity': 'Zurich',
#   'diedCountry': 'Switzerland',
#   'diedCountryCode': 'CH',
#   'firstname': 'Wolfgang',
#   'gender': 'male',
#   'id': '50',
#   'prizes': [{'affiliations': [{'city': 'Princeton, NJ',
#       'country': 'USA',
#       'name': 'Princeton University'}],
#     'category': 'physics',
#     'motivation': '"for the discovery of the Exclusion Principle, also called the Pauli Principle"',
#     'share': '1',
#     'year': '1945'}],
#   'surname': 'Pauli'},
#  {'_id': ObjectId('5c49663d41ddc1194e950828'),
#   'born': '1882-04-21',
#   'bornCity': 'Cambridge, MA',
#   'bornCountry': 'USA',
#   'bornCountryCode': 'US',
#   'died': '1961-08-20',
#   'diedCity': 'Randolph, NH',
#   'diedCountry': 'USA',
#   'diedCountryCode': 'US',
#   'firstname': 'Percy Williams',
#   'gender': 'male',
#   'id': '51',
#   'prizes': [{'affiliations': [{'city': 'Cambridge, MA',
#       'country': 'USA',
#       'name': 'Harvard University'}],
#     'category': 'physics',
#     'motivation': '"for the invention of an apparatus to produce extremely high pressures, and for the discoveries he made therewith in the field of high pressure physics"',
#     'share': '1',
#     'year': '1946'}],
#   'surname': 'Bridgman'},
#  {'_id': ObjectId('5c49663d41ddc1194e950829'),
#   'born': '1892-09-06',
#   'bornCity': 'Bradford',
#   'bornCountry': 'United Kingdom',
#   'bornCountryCode': 'GB',
#   'died': '1965-04-21',
#   'diedCity': 'Edinburgh',
#   'diedCountry': 'Scotland',
#   'diedCountryCode': 'GB',
#   'firstname': 'Sir Edward Victor',
#   'gender': 'male',
#   'id': '52',
#   'prizes': [{'affiliations': [{'city': 'London',
#       'country': 'United Kingdom',
#       'name': 'Department of Scientific and Industrial Research'}],
#     'category': 'physics',
#     'motivation': '"for his investigations of the physics of the upper atmosphere especially for the discovery of the so-called Appleton layer"',
#     'share': '1',
#     'year': '1947'}],
#   'surname': 'Appleton'},
#  {'_id': ObjectId('5c49663d41ddc1194e95082a'),
#   'born': '1897-11-18',
#   'bornCity': 'London',
#   'bornCountry': 'United Kingdom',
#   'bornCountryCode': 'GB',
#   'died': '1974-07-13',
#   'diedCity': 'London',
#   'diedCountry': 'United Kingdom',
#   'diedCountryCode': 'GB',
#   'firstname': 'Patrick Maynard Stuart',
#   'gender': 'male',
#   'id': '53',
#   'prizes': [{'affiliations': [{'city': 'Manchester',
#       'country': 'United Kingdom',
#       'name': 'Victoria University'}],
#     'category': 'physics',
#     'motivation': '"for his development of the Wilson cloud chamber method, and his discoveries therewith in the fields of nuclear physics and cosmic radiation"',
#     'share': '1',
#     'year': '1948'}],
#   'surname': 'Blackett'},
#  {'_id': ObjectId('5c49663d41ddc1194e95082b'),
#   'born': '1907-01-23',
#   'bornCity': 'Tokyo',
#   'bornCountry': 'Japan',
#   'bornCountryCode': 'JP',
#   'died': '1981-09-08',
#   'diedCity': 'Kyoto',
#   'diedCountry': 'Japan',
#   'diedCountryCode': 'JP',
#   'firstname': 'Hideki',
#   'gender': 'male',
#   'id': '54',
#   'prizes': [{'affiliations': [{'city': 'Kyoto',
#       'country': 'Japan',
#       'name': 'Kyoto Imperial University'},
#      {'city': 'New York, NY',
#       'country': 'USA',
#       'name': 'Columbia University'}],
#     'category': 'physics',
#     'motivation': '"for his prediction of the existence of mesons on the basis of theoretical work on nuclear forces"',
#     'share': '1',
#     'year': '1949'}],
#   'surname': 'Yukawa'},
#  {'_id': ObjectId('5c49663d41ddc1194e95082c'),
#   'born': '1903-12-05',
#   'bornCity': 'Tonbridge',
#   'bornCountry': 'United Kingdom',
#   'bornCountryCode': 'GB',
#   'died': '1969-08-09',
#   'diedCountry': 'Italy',
#   'diedCountryCode': 'IT',
#   'firstname': 'Cecil Frank',
#   'gender': 'male',
#   'id': '55',
#   'prizes': [{'affiliations': [{'city': 'Bristol',
#       'country': 'United Kingdom',
#       'name': 'Bristol University'}],
#     'category': 'physics',
#     'motivation': '"for his development of the photographic method of studying nuclear processes and his discoveries regarding mesons made with this method"',
#     'share': '1',
#     'year': '1950'}],
#   'surname': 'Powell'},
#  {'_id': ObjectId('5c49663d41ddc1194e95082d'),
#   'born': '1897-05-27',
#   'bornCity': 'Todmorden',
#   'bornCountry': 'United Kingdom',
#   'bornCountryCode': 'GB',
#   'died': '1967-09-18',
#   'diedCity': 'Cambridge',
#   'diedCountry': 'United Kingdom',
#   'diedCountryCode': 'GB',
#   'firstname': 'Sir John Douglas',
#   'gender': 'male',
#   'id': '56',
#   'prizes': [{'affiliations': [{'city': 'Harwell, Berkshire',
#       'country': 'United Kingdom',
#       'name': 'Atomic Energy Research Establishment'}],
#     'category': 'physics',
#     'motivation': '"for their pioneer work on the transmutation of atomic nuclei by artificially accelerated atomic particles"',
#     'share': '2',
#     'year': '1951'}],
#   'surname': 'Cockcroft'},
#  {'_id': ObjectId('5c49663d41ddc1194e95082e'),
#   'born': '1903-10-06',
#   'bornCity': 'Dungarvan',
#   'bornCountry': 'Ireland',
#   'bornCountryCode': 'IE',
#   'died': '1995-06-25',
#   'diedCity': 'Belfast',
#   'diedCountry': 'Northern Ireland',
#   'diedCountryCode': 'GB',
#   'firstname': 'Ernest Thomas Sinton',
#   'gender': 'male',
#   'id': '57',
#   'prizes': [{'affiliations': [{'city': 'Dublin',
#       'country': 'Ireland',
#       'name': 'Trinity College'}],
#     'category': 'physics',
#     'motivation': '"for their pioneer work on the transmutation of atomic nuclei by artificially accelerated atomic particles"',
#     'share': '2',
#     'year': '1951'}],
#   'surname': 'Walton'},
#  {'_id': ObjectId('5c49663d41ddc1194e95082f'),
#   'born': '1905-10-23',
#   'bornCity': 'Zurich',
#   'bornCountry': 'Switzerland',
#   'bornCountryCode': 'CH',
#   'died': '1983-09-10',
#   'diedCity': 'Zurich',
#   'diedCountry': 'Switzerland',
#   'diedCountryCode': 'CH',
#   'firstname': 'Felix',
#   'gender': 'male',
#   'id': '58',
#   'prizes': [{'affiliations': [{'city': 'Stanford, CA',
#       'country': 'USA',
#       'name': 'Stanford University'}],
#     'category': 'physics',
#     'motivation': '"for their development of new methods for nuclear magnetic precision measurements and discoveries in connection therewith"',
#     'share': '2',
#     'year': '1952'}],
#   'surname': 'Bloch'},
#  {'_id': ObjectId('5c49663d41ddc1194e950830'),
#   'born': '1912-08-30',
#   'bornCity': 'Taylorville, IL',
#   'bornCountry': 'USA',
#   'bornCountryCode': 'US',
#   'died': '1997-03-07',
#   'diedCity': 'Cambridge, MA',
#   'diedCountry': 'USA',
#   'diedCountryCode': 'US',
#   'firstname': 'Edward Mills',
#   'gender': 'male',
#   'id': '59',
#   'prizes': [{'affiliations': [{'city': 'Cambridge, MA',
#       'country': 'USA',
#       'name': 'Harvard University'}],
#     'category': 'physics',
#     'motivation': '"for their development of new methods for nuclear magnetic precision measurements and discoveries in connection therewith"',
#     'share': '2',
#     'year': '1952'}],
#   'surname': 'Purcell'},
#  {'_id': ObjectId('5c49663d41ddc1194e950831'),
#   'born': '1888-07-16',
#   'bornCity': 'Amsterdam',
#   'bornCountry': 'the Netherlands',
#   'bornCountryCode': 'NL',
#   'died': '1966-03-10',
#   'diedCity': 'Groningen',
#   'diedCountry': 'the Netherlands',
#   'diedCountryCode': 'NL',
#   'firstname': 'Frits',
#   'gender': 'male',
#   'id': '60',
#   'prizes': [{'affiliations': [{'city': 'Groningen',
#       'country': 'the Netherlands',
#       'name': 'Groningen University'}],
#     'category': 'physics',
#     'motivation': '"for his demonstration of the phase contrast method, especially for his invention of the phase contrast microscope"',
#     'share': '1',
#     'year': '1953'}],
#   'surname': 'Zernike'},
#  {'_id': ObjectId('5c49663d41ddc1194e950832'),
#   'born': '1882-12-11',
#   'bornCity': 'Breslau (now Wroclaw)',
#   'bornCountry': 'Germany (now Poland)',
#   'bornCountryCode': 'PL',
#   'died': '1970-01-05',
#   'diedCity': 'Göttingen',
#   'diedCountry': 'West Germany (now Germany)',
#   'diedCountryCode': 'DE',
#   'firstname': 'Max',
#   'gender': 'male',
#   'id': '61',
#   'prizes': [{'affiliations': [{'city': 'Edinburgh',
#       'country': 'United Kingdom',
#       'name': 'Edinburgh University'}],
#     'category': 'physics',
#     'motivation': '"for his fundamental research in quantum mechanics, especially for his statistical interpretation of the wavefunction"',
#     'share': '2',
#     'year': '1954'}],
#   'surname': 'Born'},
#  {'_id': ObjectId('5c49663d41ddc1194e950833'),
#   'born': '1891-01-08',
#   'bornCity': 'Oranienburg',
#   'bornCountry': 'Germany',
#   'bornCountryCode': 'DE',
#   'died': '1957-02-08',
#   'diedCity': 'Heidelberg',
#   'diedCountry': 'West Germany (now Germany)',
#   'diedCountryCode': 'DE',
#   'firstname': 'Walther',
#   'gender': 'male',
#   'id': '62',
#   'prizes': [{'affiliations': [{'city': 'Heidelberg',
#       'country': 'Federal Republic of Germany',
#       'name': 'University of Heidelberg'},
#      {'city': 'Heidelberg',
#       'country': 'Federal Republic of Germany',
#       'name': 'Max-Planck-Institut für medizinische Forschung'}],
#     'category': 'physics',
#     'motivation': '"for the coincidence method and his discoveries made therewith"',
#     'share': '2',
#     'year': '1954'}],
#   'surname': 'Bothe'},
#  {'_id': ObjectId('5c49663d41ddc1194e950834'),
#   'born': '1913-07-12',
#   'bornCity': 'Los Angeles, CA',
#   'bornCountry': 'USA',
#   'bornCountryCode': 'US',
#   'died': '2008-05-15',
#   'diedCity': 'Tucson, AZ',
#   'diedCountry': 'USA',
#   'diedCountryCode': 'US',
#   'firstname': 'Willis Eugene',
#   'gender': 'male',
#   'id': '63',
#   'prizes': [{'affiliations': [{'city': 'Stanford, CA',
#       'country': 'USA',
#       'name': 'Stanford University'}],
#     'category': 'physics',
#     'motivation': '"for his discoveries concerning the fine structure of the hydrogen spectrum"',
#     'share': '2',
#     'year': '1955'}],
#   'surname': 'Lamb'},
#  {'_id': ObjectId('5c49663d41ddc1194e950835'),
#   'born': '1911-01-26',
#   'bornCity': 'Blankenburg',
#   'bornCountry': 'Germany',
#   'bornCountryCode': 'DE',
#   'died': '1993-03-20',
#   'diedCity': 'Dallas, TX',
#   'diedCountry': 'USA',
#   'diedCountryCode': 'US',
#   'firstname': 'Polykarp',
#   'gender': 'male',
#   'id': '64',
#   'prizes': [{'affiliations': [{'city': 'New York, NY',
#       'country': 'USA',
#       'name': 'Columbia University'}],
#     'category': 'physics',
#     'motivation': '"for his precision determination of the magnetic moment of the electron"',
#     'share': '2',
#     'year': '1955'}],
#   'surname': 'Kusch'},
#  {'_id': ObjectId('5c49663d41ddc1194e950836'),
#   'born': '1910-02-13',
#   'bornCity': 'London',
#   'bornCountry': 'United Kingdom',
#   'bornCountryCode': 'GB',
#   'died': '1989-08-12',
#   'diedCity': 'Palo Alto, CA',
#   'diedCountry': 'USA',
#   'diedCountryCode': 'US',
#   'firstname': 'William Bradford',
#   'gender': 'male',
#   'id': '65',
#   'prizes': [{'affiliations': [{'city': 'Mountain View, CA',
#       'country': 'USA',
#       'name': 'Semiconductor Laboratory of Beckman Instruments, Inc.'}],
#     'category': 'physics',
#     'motivation': '"for their researches on semiconductors and their discovery of the transistor effect"',
#     'share': '3',
#     'year': '1956'}],
#   'surname': 'Shockley'},
#  {'_id': ObjectId('5c49663d41ddc1194e950837'),
#   'born': '1908-05-23',
#   'bornCity': 'Madison, WI',
#   'bornCountry': 'USA',
#   'bornCountryCode': 'US',
#   'died': '1991-01-30',
#   'diedCity': 'Boston, MA',
#   'diedCountry': 'USA',
#   'diedCountryCode': 'US',
#   'firstname': 'John',
#   'gender': 'male',
#   'id': '66',
#   'prizes': [{'affiliations': [{'city': 'Urbana, IL',
#       'country': 'USA',
#       'name': 'University of Illinois'}],
#     'category': 'physics',
#     'motivation': '"for their researches on semiconductors and their discovery of the transistor effect"',
#     'share': '3',
#     'year': '1956'},
#    {'affiliations': [{'city': 'Urbana, IL',
#       'country': 'USA',
#       'name': 'University of Illinois'}],
#     'category': 'physics',
#     'motivation': '"for their jointly developed theory of superconductivity, usually called the BCS-theory"',
#     'share': '3',
#     'year': '1972'}],
#   'surname': 'Bardeen'},
#  {'_id': ObjectId('5c49663d41ddc1194e950838'),
#   'born': '1902-02-10',
#   'bornCity': 'Amoy',
#   'bornCountry': 'China',
#   'bornCountryCode': 'CN',
#   'died': '1987-10-13',
#   'diedCity': 'Seattle, WA',
#   'diedCountry': 'USA',
#   'diedCountryCode': 'US',
#   'firstname': 'Walter Houser',
#   'gender': 'male',
#   'id': '67',
#   'prizes': [{'affiliations': [{'city': 'Murray Hill, NJ',
#       'country': 'USA',
#       'name': 'Bell Telephone Laboratories'}],
#     'category': 'physics',
#     'motivation': '"for their researches on semiconductors and their discovery of the transistor effect"',
#     'share': '3',
#     'year': '1956'}],
#   'surname': 'Brattain'},
#  {'_id': ObjectId('5c49663d41ddc1194e950839'),
#   'born': '1922-09-22',
#   'bornCity': 'Hofei, Anhwei',
#   'bornCountry': 'China',
#   'bornCountryCode': 'CN',
#   'died': '0000-00-00',
#   'firstname': 'Chen Ning',
#   'gender': 'male',
#   'id': '68',
#   'prizes': [{'affiliations': [{'city': 'Princeton, NJ',
#       'country': 'USA',
#       'name': 'Institute for Advanced Study'}],
#     'category': 'physics',
#     'motivation': '"for their penetrating investigation of the so-called parity laws which has led to important discoveries regarding the elementary particles"',
#     'share': '2',
#     'year': '1957'}],
#   'surname': 'Yang'},
#  {'_id': ObjectId('5c49663d41ddc1194e95083a'),
#   'born': '1926-11-24',
#   'bornCity': 'Shanghai',
#   'bornCountry': 'China',
#   'bornCountryCode': 'CN',
#   'died': '0000-00-00',
#   'firstname': 'Tsung-Dao (T.D.)',
#   'gender': 'male',
#   'id': '69',
#   'prizes': [{'affiliations': [{'city': 'New York, NY',
#       'country': 'USA',
#       'name': 'Columbia University'}],
#     'category': 'physics',
#     'motivation': '"for their penetrating investigation of the so-called parity laws which has led to important discoveries regarding the elementary particles"',
#     'share': '2',
#     'year': '1957'}],
#   'surname': 'Lee'},
#  {'_id': ObjectId('5c49663d41ddc1194e95083b'),
#   'born': '1904-07-28',
#   'bornCity': 'Novaya Chigla',
#   'bornCountry': 'Russia',
#   'bornCountryCode': 'RU',
#   'died': '1990-01-06',
#   'diedCountry': 'USSR',
#   'diedCountryCode': 'RU',
#   'firstname': 'Pavel Alekseyevich',
#   'gender': 'male',
#   'id': '70',
#   'prizes': [{'affiliations': [{'city': 'Moscow',
#       'country': 'USSR',
#       'name': 'P.N. Lebedev Physical Institute'}],
#     'category': 'physics',
#     'motivation': '"for the discovery and the interpretation of the Cherenkov effect"',
#     'share': '3',
#     'year': '1958'}],
#   'surname': 'Cherenkov'},
#  {'_id': ObjectId('5c49663d41ddc1194e95083c'),
#   'born': '1895-07-08',
#   'bornCity': 'Vladivostok',
#   'bornCountry': 'Russia',
#   'bornCountryCode': 'RU',
#   'died': '1971-04-12',
#   'diedCity': 'Moscow',
#   'diedCountry': 'USSR (now Russia)',
#   'diedCountryCode': 'RU',
#   'firstname': 'Igor Yevgenyevich',
#   'gender': 'male',
#   'id': '71',
#   'prizes': [{'affiliations': [{'city': 'Moscow',
#       'country': 'USSR',
#       'name': 'University of Moscow'},
#      {'city': 'Moscow',
#       'country': 'USSR',
#       'name': 'P.N. Lebedev Physical Institute'}],
#     'category': 'physics',
#     'motivation': '"for the discovery and the interpretation of the Cherenkov effect"',
#     'share': '3',
#     'year': '1958'}],
#   'surname': 'Tamm'},
#  {'_id': ObjectId('5c49663d41ddc1194e95083d'),
#   'born': '1905-02-01',
#   'bornCity': 'Tivoli',
#   'bornCountry': 'Italy',
#   'bornCountryCode': 'IT',
#   'died': '1989-04-22',
#   'diedCity': 'Lafayette, CA',
#   'diedCountry': 'USA',
#   'diedCountryCode': 'US',
#   'firstname': 'Emilio Gino',
#   'gender': 'male',
# ...
#   'id': '933',
#   'prizes': [{'affiliations': [{'city': 'Groningen',
#       'country': 'the Netherlands',
#       'name': 'University of Groningen'}],
#     'category': 'chemistry',
#     'motivation': '"for the design and synthesis of molecular machines"',
#     'share': '3',
#     'year': '2016'}],
#   'surname': 'Feringa'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b81'),
#   'born': '1951-08-10',
#   'bornCity': 'Bogotá',
#   'bornCountry': 'Colombia',
#   'bornCountryCode': 'CO',
#   'died': '0000-00-00',
#   'firstname': 'Juan Manuel',
#   'gender': 'male',
#   'id': '934',
#   'prizes': [{'affiliations': [[]],
#     'category': 'peace',
#     'motivation': '"for his resolute efforts to bring the country\'s more than 50-year-long civil war to an end"',
#     'share': '1',
#     'year': '2016'}],
#   'surname': 'Santos'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b82'),
#   'born': '1948-10-09',
#   'bornCity': 'London',
#   'bornCountry': 'United Kingdom',
#   'bornCountryCode': 'GB',
#   'died': '0000-00-00',
#   'firstname': 'Oliver',
#   'gender': 'male',
#   'id': '935',
#   'prizes': [{'affiliations': [{'city': 'Cambridge, MA',
#       'country': 'USA',
#       'name': 'Harvard University'}],
#     'category': 'economics',
#     'motivation': '"for their contributions to contract theory"',
#     'share': '2',
#     'year': '2016'}],
#   'surname': 'Hart'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b83'),
#   'born': '1949-04-18',
#   'bornCity': 'Helsinki',
#   'bornCountry': 'Finland',
#   'bornCountryCode': 'FI',
#   'died': '0000-00-00',
#   'firstname': 'Bengt',
#   'gender': 'male',
#   'id': '936',
#   'prizes': [{'affiliations': [{'city': 'Cambridge, MA',
#       'country': 'USA',
#       'name': 'Massachusetts Institute of Technology (MIT)'}],
#     'category': 'economics',
#     'motivation': '"for their contributions to contract theory"',
#     'share': '2',
#     'year': '2016'}],
#   'surname': 'Holmström'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b84'),
#   'born': '1941-05-24',
#   'bornCity': 'Duluth, MN',
#   'bornCountry': 'USA',
#   'bornCountryCode': 'US',
#   'died': '0000-00-00',
#   'firstname': 'Bob',
#   'gender': 'male',
#   'id': '937',
#   'prizes': [{'affiliations': [[]],
#     'category': 'literature',
#     'motivation': '"for having created new poetic expressions within the great American song tradition"',
#     'share': '1',
#     'year': '2016'}],
#   'surname': 'Dylan'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b85'),
#   'born': '1945-05-03',
#   'bornCity': 'New York, NY',
#   'bornCountry': 'USA',
#   'bornCountryCode': 'US',
#   'died': '0000-00-00',
#   'firstname': 'Jeffrey C.',
#   'gender': 'male',
#   'id': '938',
#   'prizes': [{'affiliations': [{'city': 'Maine, ME',
#       'country': 'USA',
#       'name': 'University of Maine'}],
#     'category': 'medicine',
#     'motivation': '"for their discoveries of molecular mechanisms controlling the circadian rhythm"',
#     'share': '3',
#     'year': '2017'}],
#   'surname': 'Hall'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b86'),
#   'born': '1944-03-07',
#   'bornCity': 'Kansas City, MO',
#   'bornCountry': 'USA',
#   'bornCountryCode': 'US',
#   'died': '0000-00-00',
#   'firstname': 'Michael',
#   'gender': 'male',
#   'id': '939',
#   'prizes': [{'affiliations': [{'city': 'Waltham, MA',
#       'country': 'USA',
#       'name': 'Brandeis University'},
#      {'name': 'Howard Hughes Medical Institute'}],
#     'category': 'medicine',
#     'motivation': '"for their discoveries of molecular mechanisms controlling the circadian rhythm"',
#     'share': '3',
#     'year': '2017'}],
#   'surname': 'Rosbash'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b87'),
#   'born': '1949-03-28',
#   'bornCity': 'Miami, FL',
#   'bornCountry': 'USA',
#   'bornCountryCode': 'US',
#   'died': '0000-00-00',
#   'firstname': 'Michael W.',
#   'gender': 'male',
#   'id': '940',
#   'prizes': [{'affiliations': [{'city': 'New York, NY',
#       'country': 'USA',
#       'name': 'Rockefeller University'}],
#     'category': 'medicine',
#     'motivation': '"for their discoveries of molecular mechanisms controlling the circadian rhythm"',
#     'share': '3',
#     'year': '2017'}],
#   'surname': 'Young'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b88'),
#   'born': '1932-09-29',
#   'bornCity': 'Berlin',
#   'bornCountry': 'Germany',
#   'bornCountryCode': 'DE',
#   'died': '0000-00-00',
#   'firstname': 'Rainer',
#   'gender': 'male',
#   'id': '941',
#   'prizes': [{'affiliations': [{'name': 'LIGO/VIRGO Collaboration'},
#      {'city': 'Cambridge, MA',
#       'country': 'USA',
#       'name': 'Massachusetts Institute of Technology (MIT)'}],
#     'category': 'physics',
#     'motivation': '"for decisive contributions to the LIGO detector and the observation of gravitational waves"',
#     'share': '2',
#     'year': '2017'}],
#   'surname': 'Weiss'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b89'),
#   'born': '1936-01-27',
#   'bornCity': 'Omaha, NE',
#   'bornCountry': 'USA',
#   'bornCountryCode': 'US',
#   'died': '0000-00-00',
#   'firstname': 'Barry C.',
#   'gender': 'male',
#   'id': '942',
#   'prizes': [{'affiliations': [{'name': 'LIGO/VIRGO Collaboration'},
#      {'city': 'Pasadena, CA',
#       'country': 'USA',
#       'name': 'California Institute of Technology (Caltech)'}],
#     'category': 'physics',
#     'motivation': '"for decisive contributions to the LIGO detector and the observation of gravitational waves"',
#     'share': '4',
#     'year': '2017'}],
#   'surname': 'Barish'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b8a'),
#   'born': '1940-06-01',
#   'bornCity': 'Logan, UT',
#   'bornCountry': 'USA',
#   'bornCountryCode': 'US',
#   'died': '0000-00-00',
#   'firstname': 'Kip S.',
#   'gender': 'male',
#   'id': '943',
#   'prizes': [{'affiliations': [{'name': 'LIGO/VIRGO Collaboration'},
#      {'city': 'Pasadena, CA',
#       'country': 'USA',
#       'name': 'California Institute of Technology (Caltech)'}],
#     'category': 'physics',
#     'motivation': '"for decisive contributions to the LIGO detector and the observation of gravitational waves"',
#     'share': '4',
#     'year': '2017'}],
#   'surname': 'Thorne'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b8b'),
#   'born': '1942-06-08',
#   'bornCity': 'Aigle',
#   'bornCountry': 'Switzerland',
#   'bornCountryCode': 'CH',
#   'died': '0000-00-00',
#   'firstname': 'Jacques',
#   'gender': 'male',
#   'id': '944',
#   'prizes': [{'affiliations': [{'city': 'Lausanne',
#       'country': 'Switzerland',
#       'name': 'University of Lausanne'}],
#     'category': 'chemistry',
#     'motivation': '"for developing cryo-electron microscopy for the high-resolution structure determination of biomolecules in solution"',
#     'share': '3',
#     'year': '2017'}],
#   'surname': 'Dubochet'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b8c'),
#   'born': '1940-09-12',
#   'bornCity': 'Siegen',
#   'bornCountry': 'Germany',
#   'bornCountryCode': 'DE',
#   'died': '0000-00-00',
#   'firstname': 'Joachim',
#   'gender': 'male',
#   'id': '945',
#   'prizes': [{'affiliations': [{'city': 'New York, NY',
#       'country': 'USA',
#       'name': 'Columbia University'}],
#     'category': 'chemistry',
#     'motivation': '"for developing cryo-electron microscopy for the high-resolution structure determination of biomolecules in solution"',
#     'share': '3',
#     'year': '2017'}],
#   'surname': 'Frank'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b8d'),
#   'born': '1945-07-19',
#   'bornCity': 'Edinburgh',
#   'bornCountry': 'Scotland',
#   'bornCountryCode': 'GB',
#   'died': '0000-00-00',
#   'firstname': 'Richard',
#   'gender': 'male',
#   'id': '946',
#   'prizes': [{'affiliations': [{'city': 'Cambridge',
#       'country': 'United Kingdom',
#       'name': 'MRC Laboratory of Molecular Biology'}],
#     'category': 'chemistry',
#     'motivation': '"for developing cryo-electron microscopy for the high-resolution structure determination of biomolecules in solution"',
#     'share': '3',
#     'year': '2017'}],
#   'surname': 'Henderson'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b8e'),
#   'born': '1954-11-08',
#   'bornCity': 'Nagasaki',
#   'bornCountry': 'Japan',
#   'bornCountryCode': 'JP',
#   'died': '0000-00-00',
#   'firstname': 'Kazuo',
#   'gender': 'male',
#   'id': '947',
#   'prizes': [{'affiliations': [[]],
#     'category': 'literature',
#     'motivation': '"who, in novels of great emotional force, has uncovered the abyss beneath our illusory sense of connection with the world"',
#     'share': '1',
#     'year': '2017'}],
#   'surname': 'Ishiguro'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b8f'),
#   'born': '0000-00-00',
#   'died': '0000-00-00',
#   'firstname': 'International Campaign to Abolish Nuclear Weapons (ICAN)',
#   'gender': 'org',
#   'id': '948',
#   'prizes': [{'affiliations': [[]],
#     'category': 'peace',
#     'motivation': '"for its work to draw attention to the catastrophic humanitarian consequences of any use of nuclear weapons and for its ground-breaking efforts to achieve a treaty-based prohibition of such weapons"',
#     'share': '1',
#     'year': '2017'}]},
#  {'_id': ObjectId('5c49663d41ddc1194e950b90'),
#   'born': '1945-09-12',
#   'bornCity': 'East Orange, NJ',
#   'bornCountry': 'USA',
#   'bornCountryCode': 'US',
#   'died': '0000-00-00',
#   'firstname': 'Richard H.',
#   'gender': 'male',
#   'id': '949',
#   'prizes': [{'affiliations': [{'city': 'Chicago, IL',
#       'country': 'USA',
#       'name': 'University of Chicago'}],
#     'category': 'economics',
#     'motivation': '"for his contributions to behavioural economics"',
#     'share': '1',
#     'year': '2017'}],
#   'surname': 'Thaler'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b91'),
#   'born': '1948-08-07',
#   'bornCity': 'Alice, TX',
#   'bornCountry': 'USA',
#   'bornCountryCode': 'US',
#   'died': '0000-00-00',
#   'firstname': 'James P.',
#   'gender': 'male',
#   'id': '958',
#   'prizes': [{'affiliations': [{'city': 'San Francisco, CA',
#       'country': 'USA',
#       'name': 'Parker Institute for Cancer Immunotherapy'},
#      {'city': 'Houston, TX',
#       'country': 'USA',
#       'name': 'University of Texas MD Anderson Cancer Center'}],
#     'category': 'medicine',
#     'motivation': '"for their discovery of cancer therapy by inhibition of negative immune regulation"',
#     'share': '2',
#     'year': '2018'}],
#   'surname': 'Allison'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b92'),
#   'born': '1942-01-27',
#   'bornCity': 'Kyoto',
#   'bornCountry': 'Japan',
#   'bornCountryCode': 'JP',
#   'died': '0000-00-00',
#   'firstname': 'Tasuku',
#   'gender': 'male',
#   'id': '959',
#   'prizes': [{'affiliations': [{'city': 'Kyoto',
#       'country': 'Japan',
#       'name': 'Kyoto University'}],
#     'category': 'medicine',
#     'motivation': '"for their discovery of cancer therapy by inhibition of negative immune regulation"',
#     'share': '2',
#     'year': '2018'}],
#   'surname': 'Honjo'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b93'),
#   'born': '1922-09-02',
#   'bornCity': 'New York, NY',
#   'bornCountry': 'USA',
#   'bornCountryCode': 'US',
#   'died': '0000-00-00',
#   'firstname': 'Arthur',
#   'gender': 'male',
#   'id': '960',
#   'prizes': [{'affiliations': [{'city': 'Holmdel, NJ',
#       'country': 'USA',
#       'name': 'Bell Laboratories'}],
#     'category': 'physics',
#     'motivation': '"for the optical tweezers and their application to biological systems"',
#     'overallMotivation': '“for groundbreaking inventions in the field of laser physics”',
#     'share': '2',
#     'year': '2018'}],
#   'surname': 'Ashkin'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b94'),
#   'born': '1944-06-22',
#   'bornCity': 'Albertville',
#   'bornCountry': 'France',
#   'bornCountryCode': 'FR',
#   'died': '0000-00-00',
#   'firstname': 'Gérard',
#   'gender': 'male',
#   'id': '961',
#   'prizes': [{'affiliations': [{'city': 'Palaiseau',
#       'country': 'France',
#       'name': 'École Polytechnique'},
#      {'city': 'Ann Arbor, MI',
#       'country': 'USA',
#       'name': 'University of Michigan'}],
#     'category': 'physics',
#     'motivation': '"for their method of generating high-intensity, ultra-short optical pulses"',
#     'overallMotivation': '“for groundbreaking inventions in the field of laser physics”',
#     'share': '4',
#     'year': '2018'}],
#   'surname': 'Mourou'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b95'),
#   'born': '0000-00-00',
#   'bornCity': 'Guelph',
#   'bornCountry': 'Canada',
#   'bornCountryCode': 'CA',
#   'died': '0000-00-00',
#   'firstname': 'Donna',
#   'gender': 'female',
#   'id': '962',
#   'prizes': [{'affiliations': [{'city': 'Waterloo',
#       'country': 'Canada',
#       'name': 'University of Waterloo'}],
#     'category': 'physics',
#     'motivation': '"for their method of generating high-intensity, ultra-short optical pulses"',
#     'overallMotivation': '“for groundbreaking inventions in the field of laser physics”',
#     'share': '4',
#     'year': '2018'}],
#   'surname': 'Strickland'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b96'),
#   'born': '1956-07-25',
#   'bornCity': 'Pittsburgh, PA',
#   'bornCountry': 'USA',
#   'bornCountryCode': 'US',
#   'died': '0000-00-00',
#   'firstname': 'Frances H.',
#   'gender': 'female',
#   'id': '963',
#   'prizes': [{'affiliations': [{'city': 'Pasadena, CA',
#       'country': 'USA',
#       'name': 'California Institute of Technology (Caltech)'}],
#     'category': 'chemistry',
#     'motivation': '"for the directed evolution of enzymes"',
#     'share': '2',
#     'year': '2018'}],
#   'surname': 'Arnold'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b97'),
#   'born': '0000-00-00',
#   'bornCity': 'Norwalk, CT',
#   'bornCountry': 'USA',
#   'bornCountryCode': 'US',
#   'died': '0000-00-00',
#   'firstname': 'George P.',
#   'gender': 'male',
#   'id': '964',
#   'prizes': [{'affiliations': [{'city': 'Columbia',
#       'country': 'USA',
#       'name': 'University of Missouri'}],
#     'category': 'chemistry',
#     'motivation': '"for the phage display of peptides and antibodies"',
#     'share': '4',
#     'year': '2018'}],
#   'surname': 'Smith'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b98'),
#   'born': '1951-04-14',
#   'bornCity': 'Leicester',
#   'bornCountry': 'United Kingdom',
#   'bornCountryCode': 'GB',
#   'died': '0000-00-00',
#   'firstname': 'Sir Gregory P.',
#   'gender': 'male',
#   'id': '965',
#   'prizes': [{'affiliations': [{'city': 'Cambridge',
#       'country': 'United Kingdom',
#       'name': 'MRC Laboratory of Molecular Biology'}],
#     'category': 'chemistry',
#     'motivation': '"for the phage display of peptides and antibodies"',
#     'share': '4',
#     'year': '2018'}],
#   'surname': 'Winter'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b99'),
#   'born': '0000-00-00',
#   'died': '0000-00-00',
#   'firstname': 'Denis',
#   'gender': 'male',
#   'id': '966',
#   'prizes': [{'affiliations': [[]],
#     'category': 'peace',
#     'motivation': '"for their efforts to end the use of sexual violence as a weapon of war and armed conflict"',
#     'share': '2',
#     'year': '2018'}],
#   'surname': 'Mukwege'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b9a'),
#   'born': '0000-00-00',
#   'died': '0000-00-00',
#   'firstname': 'Nadia',
#   'gender': 'female',
#   'id': '967',
#   'prizes': [{'affiliations': [[]],
#     'category': 'peace',
#     'motivation': '"for their efforts to end the use of sexual violence as a weapon of war and armed conflict"',
#     'share': '2',
#     'year': '2018'}],
#   'surname': 'Murad'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b9b'),
#   'born': '0000-00-00',
#   'bornCity': 'Albuquerque, NM',
#   'bornCountry': 'USA',
#   'bornCountryCode': 'US',
#   'died': '0000-00-00',
#   'firstname': 'William D.',
#   'gender': 'male',
#   'id': '968',
#   'prizes': [{'affiliations': [{'city': 'New Haven, CT',
#       'country': 'USA',
#       'name': 'Yale University'}],
#     'category': 'economics',
#     'motivation': '"for integrating climate change into long-run macroeconomic analysis"',
#     'share': '2',
#     'year': '2018'}],
#   'surname': 'Nordhaus'},
#  {'_id': ObjectId('5c49663d41ddc1194e950b9c'),
#   'born': '0000-00-00',
#   'bornCity': 'Denver, CO',
#   'bornCountry': 'USA',
#   'bornCountryCode': 'US',
#   'died': '0000-00-00',
#   'firstname': 'Paul M.',
#   'gender': 'male',
#   'id': '969',
#   'prizes': [{'affiliations': [{'city': 'New York, NY',
#       'country': 'USA',
#       'name': 'NYU Stern School of Business'}],
#     'category': 'economics',
#     'motivation': '"for integrating technological innovations into long-run macroeconomic analysis"',
#     'share': '2',
#     'year': '2018'}],
#   'surname': 'Romer'}]

# %%
n_prize = db.prizes.count_documents({})

n_laureates = db.laureates.count_documents({})

print(n_prize)

print(n_laureates)
# Out:
# 590
# 934

# %% [markdown]
# ### find_one method gives first document of a collection

# %%
first_document = db.prizes.find_one({})
print(first_document)
# Out:
# {'_id': ObjectId('5c49663841ddc1194e9505a9'), 'year': '2018', 'laureates': [{'firstname': 'Arthur', 'surname': 'Ashkin', 'id': '960', 'share': '2', 'motivation': '"for the optical tweezers and their application to biological systems"'}, {'firstname': 'Gérard', 'surname': 'Mourou', 'id': '961', 'share': '4', 'motivation': '"for their method of generating high-intensity, ultra-short optical pulses"'}, {'firstname': 'Donna', 'surname': 'Strickland', 'id': '962', 'share': '4', 'motivation': '"for their method of generating high-intensity, ultra-short optical pulses"'}], 'overallMotivation': '“for groundbreaking inventions in the field of laser physics”', 'category': 'physics'}

# %% [markdown]
# ### List of Database Names:

# %%
client.list_database_names()
# Out:
# ['nobel_api', 'local', 'admin']

# %% [markdown]
# ### List of Collection Names:

# %%
client.nobel_api.list_collection_names()
# Out:
# ['prizes', 'system.indexes', 'laureates']

# %% [markdown]
# ## Filtering Some Documents:

# %%
print(db.laureates.count_documents({
  'gender': 'female'
})
)

print(db.laureates.count_documents({
  'diedCountry': 'France'
})
)

print(db.laureates.count_documents({
  'bornCity': 'Warsaw'
}))

print(db.laureates.count_documents({
  'gender': 'female',
  'diedCountry': 'France',
  'bornCity': 'Warsaw'
}))
# Out:
# 51
# 50
# 2
# 1

# %% [markdown]
# ## Query Operators:

# %%
print(db.laureates.count_documents({
    'diedCountry' : {
        '$in' : ['USA','France']           # count documents in USA or France
    }
}))

print(db.laureates.find_one({
    'diedCountry' : {
        '$in' : ['USA','France']         # show the result which find first
    }
}))
# Out:
# 259
# {'bornCity': 'Paris', 'prizes': [{'year': '1903', 'affiliations': [{'country': 'France', 'name': 'École Polytechnique', 'city': 'Paris'}], 'share': '2', 'motivation': '"in recognition of the extraordinary services he has rendered by his discovery of spontaneous radioactivity"', 'category': 'physics'}], '_id': ObjectId('5c49663d41ddc1194e9507fa'), 'firstname': 'Antoine Henri', 'gender': 'male', 'diedCountryCode': 'FR', 'surname': 'Becquerel', 'bornCountryCode': 'FR', 'diedCountry': 'France', 'died': '1908-08-25', 'bornCountry': 'France', 'id': '4', 'born': '1852-12-15'}

# %% [markdown]
# ### Not Equal To...

# %%
print(db.laureates.count_documents({
 'diedCountry': {
  '$ne': 'France'              # not equals to
 }}))
# Out:
# 884

# %% [markdown]
# ### Greater than and less than equals to...

# %%
print(db.laureates.count_documents(
{
    'diedCountry' : {
        '$gt' : 'Belgium',
        '$lte' : 'USA'
    }
}
))
# Out:
# 455

# %% [markdown]
# The born field in a laureate collection document records the date of birth of that laureate. born values are of the form "YYYY-MM-DD", also known as ISO 8601 format. An example value is "1937-02-01", for February 1st, 1937. This format is convenient for lexicographic comparison. For example, the query:

# %%
db.laureates.count_documents({"born": {"$lt": "1900-05-07"}})
# Out:
# 327

# %% [markdown]
# #### Create a filter criteria to count (save as count) laureates who died ("diedCountry") in the USA ("USA").

# %%
# Create a filter for laureates who died in the USA
criteria = {'diedCountry': 'USA'}

# Save a count of these laureates
count = db.laureates.count_documents(criteria)
print(count)
# Out:
# 209

# %% [markdown]
# #### Create a filter criteria to count laureates who died in the United States but were born ("bornCountry") in Germany.

# %%
# Create a filter for laureates who died in the USA but were born in Germany
criteria = {'diedCountry': 'USA', 'bornCountry': 'Germany'}

# Save a count
count = db.laureates.count_documents(criteria)
print(count)
# Out:
# 5

# %% [markdown]
# #### Count laureates who died in the USA, were born in Germany, and whose first name ("firstname") was "Albert".

# %%
# Create a filter for Germany-born laureates who died in the USA and with the first name "Albert"
criteria = {'diedCountry': 'USA', 'bornCountry': 'Germany', 'firstname': 'Albert'}

# Save the count
count = db.laureates.count_documents(criteria)
print(count)
# Out:
# 1

# %% [markdown]
# #### how many laureates were born in any of "Canada", "Mexico", or "USA"?

# %%
# Save a filter for laureates born in the USA, Canada, or Mexico
criteria = {'bornCountry': {"$in": ["Canada", "Mexico",  "USA"]}}

# Count them and save the count
count = db.laureates.count_documents(criteria)
print(count)
# Out:
# 291

# %% [markdown]
# #### How many laureates died in the USA but were not born there? Save your filter as criteria and your count as count.

# %%
# Save a filter for laureates who died in the USA and were not born there
criteria = {'bornCountry': {"$ne": 'USA'}, 'diedCountry': 'USA'}

# Count them
count = db.laureates.count_documents(criteria)
print(count)
# Out:
# 69

# %% [markdown]
# ## Dot Notation: Reach Into Substructure:

# %%
db.laureates.find_one({
  "firstname": "Walter",
  "surname": "Kohn"})
# Out:
# {'_id': ObjectId('5c49663d41ddc1194e950913'),
#  'born': '1923-03-09',
#  'bornCity': 'Vienna',
#  'bornCountry': 'Austria',
#  'bornCountryCode': 'AT',
#  'died': '2016-04-19',
#  'diedCity': 'Santa Barbara, CA',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Walter',
#  'gender': 'male',
#  'id': '290',
#  'prizes': [{'affiliations': [{'city': 'Santa Barbara, CA',
#      'country': 'USA',
#      'name': 'University of California'}],
#    'category': 'chemistry',
#    'motivation': '"for his development of the density-functional theory"',
#    'share': '2',
#    'year': '1998'}],
#  'surname': 'Kohn'}

# %%
db.laureates.count_documents({
    'prizes.affiliations.name' : 'University of California'
})
# Out:
# 34

# %% [markdown]
# ### Existing Of A field is found out by:

# %%
print(db.laureates.count_documents({}))
db.laureates.count_documents({'prizes':{'$exists':True}})   # yes it does
# Out:
# 934
# 934

# %% [markdown]
# ### To check the value of a field in collection:

# %%
db.laureates.count_documents({
    'prize.0': {
        '$exists':True
    }
})
# Out:
# 0

# %% [markdown]
# #### Save a filter criteria for laureates born in (bornCountry) "Austria" with a non-Austria prizes.affiliations.country.

# %%
# Filter for laureates born in Austria with non-Austria prize affiliation
criteria = {'bornCountry': 'Austria', 'prizes.affiliations.country': {"$ne": 'Austria'}}

# Count the number of such laureates
count = db.laureates.count_documents(criteria)
print(count)
# Out:
# 10

# %% [markdown]
# #### Use a filter document (criteria) to confirm that every document in the laureates collection has a "born" field.

# %%
# Filter for documents without a "born" field
criteria = {'born': {'$exists': False}}
assert db.laureates.count_documents(criteria) == 0

# %% [markdown]
# #### Use a filter document (criteria) to fetch a laureates document with at least three elements in its "prizes" array.

# %%
# Filter for laureates with at least three prizes
criteria = {'prizes.2': {'$exists': True}}
print(db.laureates.find_one(criteria))
# Out:
# {'died': '0000-00-00', 'prizes': [{'year': '1917', 'affiliations': [[]], 'share': '1', 'category': 'peace'}, {'year': '1944', 'affiliations': [[]], 'share': '1', 'category': 'peace'}, {'year': '1963', 'affiliations': [[]], 'share': '2', 'category': 'peace'}], '_id': ObjectId('5c49663d41ddc1194e9509d2'), 'firstname': 'Comité international de la Croix Rouge (International Committee of the Red Cross)', 'gender': 'org', 'id': '482', 'born': '0000-00-00'}
